# %% [markdown]
# Function

# %%
def my_func(name):
# If you press Shift+Tab on the function, the docstring will appear
    '''
This prints out the user name!
    '''
    print('hello '+name)

# %%
my_func('keonwook')
# Out:
# hello keonwook

# %%
# Using print only displays the value, it does not store it. To store a value, you must use return.
def square(x):
    return x**2

# %%
result = square(2)
result
# Out:
# 4

# %%
def times_two(var):
    return var*2

# %%
times_two(10)
# Out:
# 20

# %% [markdown]
# Lambda function (anonymous function)

# %%
lambda var: var*2
# Out:
# <function __main__.<lambda>(var)>

# %%
st = 'hello my name is Keon'

# %%
st.lower()
# Out:
# 'hello my name is keon'

# %%
st.upper()
# Out:
# 'HELLO MY NAME IS KEON'

# %%
# split() splits a string into a list
st.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Keon']

# %%
tweet = 'Hello #sports'

# %%
tweet.split()
# Out:
# ['Hello', '#sports']

# %%
tweet.split('#')
# Out:
# ['Hello ', 'sports']

# %%
tweet.split('#')[-1]
# Out:
# 'sports'

# %%
d = {'k1' : 'v1', 'k2' : 'v2'}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
d.items()
# Out:
# dict_items([('k1', 'v1'), ('k2', 'v2')])

# %%
mylist = [1,2,3]

# %%
# pop() removes the last element
last = mylist.pop()

# %%
mylist
# Out:
# [1, 2]

# %%
mylist = [1,2,3]

# %%
mylist
# Out:
# [1, 2, 3]

# %%
# pop(a) removes and returns the element at index a
first = mylist.pop(0)

# %%
first
# Out:
# 1

# %%
mylist
# Out:
# [2, 3]

# %%
'x' in [1,2,3]
# Out:
# False

# %%
1 in mylist
# Out:
# False

# %%
2 in mylist
# Out:
# True
