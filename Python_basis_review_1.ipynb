# %% [markdown]
# Basic arithmetic operations

# %%
1+3
# Out:
# 4

# %%
2-1
# Out:
# 1

# %%
3*3
# Out:
# 9

# %%
6/3
# Out:
# 2.0

# %%
2**4
# Out:
# 16

# %% [markdown]
# String formatting using .format()

# %%
print("My name is {}, my number is {}".format('keonwook','0204'))
# Out:
# My name is keonwook, my number is 0204

# %% [markdown]
# List, Dictionary, Tuple

# %%
mylist = ['a','b','c']
mylist[1]
# Out:
# 'b'

# %%
mylist[0] = 'NEW'
mylist
# Out:
# ['NEW', 'b', 'c']

# %%
mylist.append('d')
mylist
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
mylist = [1,2,[100,200]]
mylist
# Out:
# [1, 2, [100, 200]]

# %%
mylist[2][1]
# Out:
# 200

# %%
d = {'key1':'value1','key2':'value2','key3':'value3'}
d['key2']
# Out:
# 'value2'

# %%
# Tuples are immutable, while lists are mutable
t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %%
# Sets store unique values and remove duplicates
{1,1,1,1,1,2,3,4,2,}
# Out:
# {1, 2, 3, 4}
